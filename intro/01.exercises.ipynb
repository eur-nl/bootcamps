# %% [markdown]
# ## Exercises 01

# %% [markdown]
# To ask a user for input, use the input(*prompt*) function.
# Use the scratchpad to test or read the help text.
#
# Ask the users name and print a greeting message.

# %%
# Your code here

# %%
name = input("What is your name? ")
print("Hello,", name, "!")

# %% [markdown]
# <hr style="height: 3px; margin: 0" />

# %% [markdown]
# Ask the user's first and last name, and print them in reverse order with a space between them.

# %%
# Your code here

# %%
first_name = input("What is your first name? ")
last_name = input("What is your last name? ")
print(last_name, first_name)
# print(last_name + " " + first_name)

# %% [markdown]
# <hr style="height: 3px; margin: 0" />

# %% [markdown]
# Print "30 + 20 = 50" from the variables x and y

# %%
x = 30  
y = 20

# Your code here

# %%
x = 30  
y = 20

print(x, "+", y, "=", x+y)
# print("%d + %d = %d" % (x, y, x + y))

# %% [markdown]
# <hr style="height: 3px; margin: 0" />

# %% [markdown]
# Print the outcome of (x + y) * (x + y)
# Test data : x = 4, y = 3
# Test output : 49

# %%
x = 4
y = 3

# Your code here

# %%
x = 4
y = 3

z = x + y
print(z * z)
# print(z ** 2)

# %% [markdown]
# <hr style="height: 3px; margin: 0" />

# %% [markdown]
# Pythagoras!
#
# $c = \sqrt{a^2 + b^2}$
#
# Write the value of C
# A = 3
# B = 4
#
# Hint : square root is in the math module
# ```python
# import math
# print(math.sqrt(100))
# ```

# %%
import math

A = 3
B = 4

# Your code here

# %%
import math

A = 3
B = 4
C = math.sqrt(A ** 2 + B ** 2)
print(C)

# %% [markdown]
# <hr style="height: 3px; margin: 0" />

# %% [markdown]
# Swap two variables
# In this case : x becomes 20 and y becomes 10

# %%
x = 10
y = 20

# Your code here

print(x)  # Should be 20
print(y)  # Should be 10

# %%
x = 10
y = 20

tmp = x
x = y
y = tmp

# x, y = y, x

print(x)
print(y)
